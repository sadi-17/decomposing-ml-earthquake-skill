# %%
from google.colab import drive
from pathlib import Path
import os

drive.mount('/content/drive')

ROOT = Path('/content/drive/MyDrive/quake_project_v4')
os.chdir(ROOT)

required = [
    'requirements.txt',
    'code/make_dataset.py',
    'code/run_analysis.py',
    'code/audit_outputs.py'
]

for filename in required:
    assert (ROOT / filename).is_file(), f"Missing: {filename}"

print("Project files found. Ready to continue.")
# Out:
# Mounted at /content/drive
# Project files found. Ready to continue.

# %%
# %pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.4/442.4 kB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 26.6 MB/s eta 0:00:00
# ...

# %%
# !python -u code/make_dataset.py --root "{ROOT}"
# Out:
# log          -> /content/drive/MyDrive/quake_project_v4/dataset/logs/dataset_20260921T013930Z.txt
# project root : /content/drive/MyDrive/quake_project_v4
# catalog end  : 2026-09-01 (pinned)
# seed         : 42
#
# [stage 1] download and clean catalogs   (+0.0 min)
# [1/3] ComCat global, 1930 onwards, M>=4.0
#   endpoint format: csv
#   1930-01-01 -> 1931-01-01:    296
#   1931-01-01 -> 1932-01-01:    303
#   1932-01-01 -> 1933-01-01:    255
#   1933-01-01 -> 1934-01-01:    383
#   1934-01-01 -> 1935-01-01:    311
#   1935-01-01 -> 1936-01-01:    281
#   1936-01-01 -> 1937-01-01:    291
#   1937-01-01 -> 1938-01-01:    255
#   1938-01-01 -> 1939-01-01:    347
#   1939-01-01 -> 1940-01-01:    256
#   1940-01-01 -> 1941-01-01:    274
#   1941-01-01 -> 1942-01-01:    225
#   1942-01-01 -> 1943-01-01:    200
#   1943-01-01 -> 1944-01-01:    178
#   1944-01-01 -> 1945-01-01:    139
#   1945-01-01 -> 1946-01-01:    141
#   1946-01-01 -> 1947-01-01:    179
# ...

# %%
# !python -u code/run_analysis.py \
    --root "{ROOT}" \
    --run-name v4_fresh \
    --gpu
# Out:
# log        -> /content/drive/MyDrive/quake_project_v4/results/v4_fresh/logs/analysis_20260921T023455Z.txt
# root       : /content/drive/MyDrive/quake_project_v4
# run name   : v4_fresh
# seed       : 42
# GPU        : True
# dataset    : built 2026-09-21T02:34:38, catalog end 2026-09-01, hashes match
#              comcat_global_m4         545220 events  sha 86c669896b6b
#              scedc_socal_m25           79182 events  sha 9a6b4cc514a8
#              comcat_himalaya_m4         4710 events  sha 1bbb7828a54d
#
# [stage 1] train models   (+0.0 min)
# === comcat_global_m4: n=545220, train 327132 / val 54522 / calib 81783 / test 81783, 11 features ===
#   training catboost ...
#   catboost: test AUC 0.9430 F1 0.8881 | recalibrator isotonic (ECE 0.0038)
#   training xgboost ...
#   xgboost: test AUC 0.9431 F1 0.8904 | recalibrator isotonic (ECE 0.0049)
#   training lightgbm ...
#   lightgbm: test AUC 0.9432 F1 0.8905 | recalibrator isotonic (ECE 0.0041)
# ...

# %%
# !python -u code/audit_outputs.py \
    --root "{ROOT}" \
    --run-name v4_fresh
# Out:
# auditing /content/drive/MyDrive/quake_project_v4/results/v4_fresh
#
# dataset
#   [ ok  ] comcat_global_m4: feature file matches provenance
#   [ ok  ] scedc_socal_m25: feature file matches provenance
#   [ ok  ] comcat_himalaya_m4: feature file matches provenance
#
# tables
#   [ ok  ] 20 of 20 expected tables present
#
# figures
#   [ ok  ] 14 figures present
#
# models
#   [ ok  ] comcat_global_m4: trained and recalibrated
#   [ ok  ] scedc_socal_m25: trained and recalibrated
#   [ ok  ] comcat_himalaya_m4: trained and recalibrated
#
# conformal sets
#   [ ok  ] set-size rates sum to one
#   [ ok  ] mean set size matches the identity
#
# ETAS
#   [ ok  ] comcat_global_m4: branching ratio 0.715, calibration matched
#   [ ok  ] scedc_socal_m25: branching ratio 0.950, calibration stability_limited
#   [ ok  ] comcat_himalaya_m4: branching ratio 0.950, calibration stability_limited
#   [ ok  ] 15 realisations over 3 catalogs
#
# manifest
# ...

# %%
from google.colab import files

report = ROOT / 'results' / 'v4_fresh' / 'ALL_RESULTS.html'

if report.is_file():
    files.download(str(report))
else:
    print("Report not found. Check the analysis output for errors.")
